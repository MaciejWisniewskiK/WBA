# %%
import analyzeData.analyze as a
import getData.getSchedule as gets

# data from 2024/02/22 09:14 with duration 60 minutes
srcfile1 = "getData/data_2202091460"

# data from 2024/02/22 17:00 with duration 60 minutes
srcfile2 = "getData/data_2202170060"

a.analyze_punctuality(srcfile1, "709", (52.115080, 21.018190), gets.getSchedule("709", "3021", "01"), "Jagielska 01")
a.analyze_punctuality(srcfile2, "709", (52.115080, 21.018190), gets.getSchedule("709", "3021", "01"), "Jagielska 01")

a.analyze_speed(srcfile1, [[0, 1], [0.5, 10]])
a.analyze_speed(srcfile2, [[0, 1], [0.5, 10]])
# Out:
# Autobusy linii 709 spóźniały się średnio 292.7164179104478 sekund na przystanku Jagielska 01
# Autobusy linii 709 spóźniały się średnio 168.62727272727273 sekund na przystanku Jagielska 01
